# %% [markdown]
# ###To research for future FNs
# https://opensource.com/article/18/8/pysimplegui

# %%
from difflib import SequenceMatcher # get ratio comparison between 2 variables

import json # prettify json

import time # to put browser to sleep

# %%
from difflib import SequenceMatcher

def match_ratio(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
import json

# prettify JSON example
parsed = json.loads(tags_script[21:13415])

# %%
import time

def sleep_timer(a,b):
    time.sleep(random.randint(a,b))

# %%
import re
#objects have a number of methods to help you with this:

m = re.search("is", String)
m.span() # 
m.start()
m.end()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c230853e889c> in <module>()
#       2 #objects have a number of methods to help you with this:
#       3
# ----> 4 m = re.search("is", String)
#       5 m.span() #
#       6 m.start()
#
# NameError: name 'String' is not defined

# %%
m.span()

# %% [markdown]
# #Future Builds

# %% [markdown]
# Allows user to iterate on command.
#
# *   Continue on user command
# *   List item

# %%
class for_loop:
    def __init__(self, start = 0, end, var):
        self.end = end
        self.var = var
        
        
    def loop(self):
        i = 0
        
        for i in range(len(self.var)):
            p
